# %%
pip list
# Out:
# Package                   Version
# ------------------------- -----------
# absl-py                   2.4.0
# annotated-doc             0.0.4
# annotated-types           0.7.0
# anyio                     4.13.0
# appnope                   0.1.4
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# asttokens                 3.0.1
# astunparse                1.6.3
# async-lru                 2.3.0
# attrs                     26.1.0
# babel                     2.18.0
# beautifulsoup4            4.14.3
# bleach                    6.3.0
# blis                      1.3.3
# catalogue                 2.0.10
# certifi                   2026.2.25
# cffi                      2.0.0
# charset-normalizer        3.4.6
# click                     8.3.2
# cloudpathlib              0.23.0
# comm                      0.2.3
# confection                1.3.3
# cymem                     2.0.13
# debugpy                   1.8.20
# decorator                 5.2.1
# defusedxml                0.7.1
# dnspython                 2.8.0
# email-validator           2.3.0
# executing                 2.2.1
# fastjsonschema            2.21.2
# filelock                  3.28.0
# flatbuffers               25.12.19
# fqdn                      1.5.1
# fsspec                    2026.3.0
# gast                      0.7.0
# google-pasta              0.2.0
# grpcio                    1.80.0
# h11                       0.16.0
# h5py                      3.14.0
# hf-xet                    1.4.3
# httpcore                  1.0.9
# httpx                     0.28.1
# huggingface_hub           1.12.0
# idna                      3.11
# ipykernel                 7.2.0
# ipython                   9.12.0
# ipython_pygments_lexers   1.1.1
# ipywidgets                8.1.8
# isoduration               20.11.0
# jedi                      0.19.2
# Jinja2                    3.1.6
# joblib                    1.5.3
# json5                     0.14.0
# jsonpointer               3.1.1
# jsonschema                4.26.0
# jsonschema-specifications 2025.9.1
# jupyter_client            8.8.0
# jupyter_core              5.9.1
# jupyter-events            0.12.0
# jupyter-lsp               2.3.0
# jupyter_server            2.17.0
# jupyter_server_terminals  0.5.4
# jupyterlab                4.5.6
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.28.0
# jupyterlab_widgets        3.0.16
# keras                     3.14.0
# lark                      1.3.1
# libclang                  18.1.1
# markdown-it-py            4.0.0
# MarkupSafe                3.0.3
# matplotlib-inline         0.2.1
# mdurl                     0.1.2
# mistune                   3.2.0
# ml_dtypes                 0.5.4
# mpmath                    1.3.0
# murmurhash                1.0.15
# namex                     0.1.0
# nbclient                  0.10.4
# nbconvert                 7.17.0
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# networkx                  3.6.1
# nltk                      3.9.4
# notebook                  7.5.5
# notebook_shim             0.2.4
# numpy                     2.4.3
# opt_einsum                3.4.0
# optree                    0.19.0
# packaging                 26.0
# pandas                    3.0.1
# pandocfilters             1.5.1
# parso                     0.8.6
# pexpect                   4.9.0
# pip                       26.0.1
# platformdirs              4.9.4
# preshed                   3.0.13
# prometheus_client         0.24.1
# prompt_toolkit            3.0.52
# protobuf                  7.34.1
# psutil                    7.2.2
# ptyprocess                0.7.0
# pure_eval                 0.2.3
# pycparser                 3.0
# pydantic                  2.12.5
# pydantic_core             2.41.5
# Pygments                  2.20.0
# python-dateutil           2.9.0.post0
# python-json-logger        4.1.0
# PyYAML                    6.0.3
# pyzmq                     27.1.0
# referencing               0.37.0
# regex                     2026.4.4
# requests                  2.33.1
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rfc3987-syntax            1.1.0
# rich                      14.3.3
# rpds-py                   0.30.0
# safetensors               0.7.0
# scikit-learn              1.8.0
# scipy                     1.17.1
# Send2Trash                2.1.0
# sentence-transformers     5.4.1
# setuptools                81.0.0
# shellingham               1.5.4
# six                       1.17.0
# smart_open                7.5.1
# soupsieve                 2.8.3
# spacy                     3.8.14
# spacy-legacy              3.0.12
# spacy-loggers             1.0.5
# srsly                     2.5.3
# stack-data                0.6.3
# sympy                     1.14.0
# tensorflow                2.21.0
# termcolor                 3.3.0
# terminado                 0.18.1
# tf_keras                  2.21.0
# thinc                     8.3.13
# threadpoolctl             3.6.0
# tinycss2                  1.4.0
# tokenizers                0.22.2
# torch                     2.11.0
# tornado                   6.5.5
# tqdm                      4.67.3
# traitlets                 5.14.3
# transformers              5.5.4
# typer                     0.24.1
# typing_extensions         4.15.0
# typing-inspection         0.4.2
# tzdata                    2025.3
# uri-template              1.3.0
# urllib3                   2.6.3
# wasabi                    1.1.3
# wcwidth                   0.6.0
# weasel                    1.0.0
# webcolors                 25.10.0
# webencodings              0.5.1
# websocket-client          1.9.0
# wheel                     0.46.3
# widgetsnbextension        4.0.15
# wrapt                     2.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import gensim.downloader as api

# Download embeddings (66MB, glove, trained on wikipedia, vector size: 50)
# Other options include "word2vec-google-news-300"
# More options at https://github.com/RaRe-Technologies/gensim-data
model = api.load("glove-wiki-gigaword-50")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import gensim.downloader as api
#       2
#       3 # Download embeddings (66MB, glove, trained on wikipedia, vector size: 50)
#       4 # Other options include "word2vec-google-news-300"
#
# ModuleNotFoundError: No module named 'gensim'

# %%
import gensim.downloader as api

# Download embeddings (66MB, glove, trained on wikipedia, vector size: 50)
# Other options include "word2vec-google-news-300"
# More options at https://github.com/RaRe-Technologies/gensim-data
model = api.load("glove-wiki-gigaword-50")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import gensim.downloader as api
#       2
#       3 # Download embeddings (66MB, glove, trained on wikipedia, vector size: 50)
#       4 # Other options include "word2vec-google-news-300"
#
# ModuleNotFoundError: No module named 'gensim'

# %%
import gensim.downloader as api

# Download embeddings (66MB, glove, trained on wikipedia, vector size: 50)
# Other options include "word2vec-google-news-300"
# More options at https://github.com/RaRe-Technologies/gensim-data
model = api.load("glove-wiki-gigaword-50")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import gensim.downloader as api
#       2
#       3 # Download embeddings (66MB, glove, trained on wikipedia, vector size: 50)
#       4 # Other options include "word2vec-google-news-300"
#
# ModuleNotFoundError: No module named 'gensim'

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Using cached gensim-4.4.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /Users/mahersarosh/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from gensim) (2.4.3)
# Requirement already satisfied: scipy>=1.7.0 in /Users/mahersarosh/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from gensim) (1.17.1)
# Requirement already satisfied: smart_open>=1.8.1 in /Users/mahersarosh/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from gensim) (7.5.1)
# Requirement already satisfied: wrapt in /Users/mahersarosh/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from smart_open>=1.8.1->gensim) (2.1.2)
# Using cached gensim-4.4.0-cp312-cp312-macosx_11_0_arm64.whl (24.5 MB)
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
import gensim
print(gensim.__version__)
# Out:
# 4.4.0

# %%
import gensim.downloader as api

# Download embeddings (66MB, glove, trained on wikipedia, vector size: 50)
# Other options include "word2vec-google-news-300"
# More options at https://github.com/RaRe-Technologies/gensim-data
model = api.load("glove-wiki-gigaword-50")
# Out:
# [==================================================] 100.0% 66.0/66.0MB downloaded

# %% [markdown]
# pip install pandas

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/mahersarosh/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.26.0 in /Users/mahersarosh/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from pandas) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mahersarosh/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/mahersarosh/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from urllib import request

# Get the playlist dataset file
data = request.urlopen('https://storage.googleapis.com/maps-premium/dataset/yes_complete/train.txt')

# Parse the playlist dataset file. Skip the first two lines as
# they only contain metadata
lines = data.read().decode("utf-8").split('\n')[2:]

# Remove playlists with only one song
playlists = [s.rstrip().split() for s in lines if len(s.split()) > 1]

# Load song metadata
songs_file = request.urlopen('https://storage.googleapis.com/maps-premium/dataset/yes_complete/song_hash.txt')
songs_file = songs_file.read().decode("utf-8").split('\n')
songs = [s.rstrip().split('\t') for s in songs_file]
songs_df = pd.DataFrame(data=songs, columns = ['id', 'title', 'artist'])
songs_df = songs_df.set_index('id')

# %%
print(songs_df[0:20])
# Out:
#                                                  title             artist
# id
# 0                         Gucci Time (w\/ Swizz Beatz)         Gucci Mane
# 1    Aston Martin Music (w\/ Drake & Chrisette Mich...          Rick Ross
# 2                        Get Back Up (w\/ Chris Brown)               T.I.
# 3                   Hot Toddy (w\/ Jay-Z & Ester Dean)              Usher
# 4                                         Whip My Hair             Willow
# 5                             Down On Me (w\/ 50 Cent)            Jeremih
# 6                                     Black And Yellow        Wiz Khalifa
# 7                                    Blowing Me Kisses         Soulja Boy
# 8                                          Lay It Down              Lloyd
# 9                        Good For My Money (w\/ Lloyd)          Baby Bash
# 10                                            Shake It       Elephant Man
# 11                                             My Cupp        Richie Loop
# 12                                    Who's That Chick            Rihanna
# 13                  Like A G6 (w\/ The Cataracs & Dec)  Far East Movement
# 14             DJ Got Us Fallin' In Love (w\/ Pitbull)              Usher
# 15                                        Hurt Me Soul        Lupe Fiasco
# 16                 Put It In A Love Song (w\/ Beyonce)        Alicia Keys
# 17                     All I Wants Is You (w\/ J Cole)             Miguel
# 18                                      Champagne Life              Ne-Yo
# 19                                      Find Your Love              Drake

# %%
from gensim.models import Word2Vec

# Train our Word2Vec model
model = Word2Vec(
    playlists, vector_size=32, window=20, negative=50, min_count=1, workers=4
)

# %%
import numpy as np

def print_recommendations(song_id):
    similar_songs = np.array(
        model.wv.most_similar(positive=str(song_id),topn=5)
    )[:,0]
    return  songs_df.iloc[similar_songs]

# Extract recommendations
print_recommendations(2172)
# Out:
#                          title         artist
# id
# 3167                 Unchained      Van Halen
# 2640             Red Barchetta           Rush
# 5549             November Rain  Guns N' Roses
# 6624   Everybody Wants Some!!!      Van Halen
# 2849          Run To The Hills    Iron Maiden
